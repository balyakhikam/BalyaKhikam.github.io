# %% [markdown]
# <a href="https://colab.research.google.com/github/balyakhikam/BalyaKhikam.github.io/blob/main/belajar_logika_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = 25
income = 6000000   # dalam rupiah
is_married = False
is_student = True
purchases = 3

# %% [markdown]
# # ✅ **Soal 1 — Filter Umur**
#
# Buat ekspresi boolean untuk mengecek apakah seseorang berusia di atas 20 tahun tetapi di bawah 30 tahun.
#
# # **✅ Soal 2 — Eligible for Premium User**
#
# Seseorang dianggap premium user jika:
#
# pendapatan di atas 5 juta AND
#
# sudah melakukan pembelian minimal 3 kali.
#
# Buat ekspresi boolean Python untuk menentukan apakah user ini premium.
#
# # **✅ Soal 3 — Diskon untuk Pelajar**
#
# Berikan ekspresi boolean untuk mengecek apakah user berhak mendapat diskon:
#
# dia adalah mahasiswa OR
#
# berusia di bawah 22 tahun.
#
# # **✅ Soal 4 — Risiko Kredit**
#
# User dianggap berisiko rendah jika:
#
# pendapatan lebih dari 7 juta AND NOT mahasiswa.
#
# Buat ekspresi boolean-nya.
#
# # **✅ Soal 5 — Penawaran Khusus**
#
# User memenuhi syarat penawaran khusus jika:
#
# (pembelian lebih dari 5 OR umur di atas 30)
# AND
#
# bukan mahasiswa.
#
# Buat ekspresi boolean-nya.
#
# # **🔍 Soal 6 – Kombinasi Data Analyst**
#
# Anggap seorang data analyst ingin mengambil data user yang:
#
# pendapatannya antara 4–7 juta
#
# dan (belum menikah atau mahasiswa)
#
# dan pembeliannya kurang dari 5.
#
# Buat ekspresi boolean lengkap.

# %%
#jawaban soal 1

if age > 20 and age < 30:
  print ("anda sudah dewasa")
else :
  print ("anda masih anak_anak")

#jawaban soal 2

if income > 5000000 and purchases >= 3:
  print ("anda adalah premium user")
else :
  print ("anda adalah user biasa")

#jawaban soal 3

if is_student or age < 22:
  print ("anda mendapatkan diskon")
else :
  print ("anda tidak mendapatkan diskon")

#jawbaan soal 4

if income > 7000000 and not is_student :
  print ("anda beresiko rendah")
else :
  print ("anda beresiko tinggi")

#jawaban soal 5

if (purchases > 5 or age > 30) and is_student :
  print ("anda mendapatkan penawaran khusus")
else :
  print ("anda tidak mendapatkan penawaran khusus")

#jawaban soal 6

if income >= 4000000 and income <= 7000000 and (not is_married or is_student) and purchases < 5 :
  print ("anda memenuhi syarat")
else :
  print ("anda tidak memenuhi syarat")
# Out:
# anda sudah dewasa
# anda adalah premium user
# anda mendapatkan diskon
# anda beresiko tinggi
# anda tidak mendapatkan penawaran khusus
# anda memenuhi syarat
